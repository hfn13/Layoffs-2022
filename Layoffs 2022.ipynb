# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

layoffs = pd.read_csv('layoffs.csv')
layoffs
# Out:
#             company        location        industry  total_laid_off  \
# 0            Amazon         Seattle          Retail         10000.0
# 1             Asana     SF Bay Area           Other           180.0
# 2          Protocol     SF Bay Area           Media            60.0
# 3     Nirvana Money           Miami         Finance             NaN
# 4             Sema4        Stamford      Healthcare           500.0
# ...             ...             ...             ...             ...
# 1581        Service     Los Angeles          Travel             NaN
# 1582   HopSkipDrive     Los Angeles  Transportation             8.0
# 1583    Panda Squad     SF Bay Area        Consumer             6.0
# 1584  Tamara Mellon     Los Angeles          Retail            20.0
# 1585       EasyPost  Salt Lake City       Logistics            75.0
#
#       percentage_laid_off        date     stage        country  funds_raised
# ...

# %%
layoffs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1586 entries, 0 to 1585
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   company              1586 non-null   object
#  1   location             1586 non-null   object
#  2   industry             1583 non-null   object
#  3   total_laid_off       1139 non-null   float64
#  4   percentage_laid_off  1058 non-null   float64
#  5   date                 1586 non-null   object
#  6   stage                1582 non-null   object
#  7   country              1586 non-null   object
#  8   funds_raised         1481 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 111.6+ KB

# %%
print(f'Total number of companies in the dataset are {len(layoffs.company.unique())}')
print()
print('The companies included are: ')
list(layoffs.company.unique())
# Out:
# Total number of companies in the dataset are 1334
#
# The companies included are:
# ['Amazon',
#  'Asana',
#  'Protocol',
#  'Nirvana Money',
#  'Sema4',
#  'Pipedrive',
#  'Intercom',
#  'Science 37 ',
#  'Cardlytics',
#  'Shopee',
#  'Veev',
#  'GoTo Group',
#  'Juul',
#  'InfluxData',
#  'Coinbase',
#  'SoundHound',
#  'Wistia',
#  'Ocavu',
#  'Reforge',
#  'SendCloud',
#  'Wavely',
#  'ZenBusiness',
#  'Meta',
#  'Redfin',
#  'Flyhomes',
#  'AvantStay',
#  'Root Insurance',
#  'Cameo',
#  'Plum',
#  'Kabam',
#  'Amobee',
#  'Coursera',
#  'Faze Medicines',
#  'RingCentral',
#  'Spotify',
#  'Repertoire Immune Medicines',
#  'Astra',
#  'Beat',
#  'SADA',
#  'Salesforce',
#  'Unacademy',
#  'Zendesk',
#  'Dock',
#  'Code42',
#  'Domino Data Lab',
#  'Varonis',
#  'Brainly',
#  'Practically',
#  'Twitter',
#  'Udaan',
#  'Planetly',
#  'Exodus',
#  'Benitago Group',
#  'Mythical Games',
#  'Stripe',
#  'Lyft',
#  'Pleo',
#  'Delivery Hero',
#  'Shippo',
#  'Affirm',
# ...

# %%
print(f'Total number of countries in dataset {len(layoffs.country.unique())}')
print()
print('Number of companies per country')

layoffs.country.value_counts()
# Out:
# Total number of countries in dataset 54
#
# Number of companies per country
# United States           1062
# India                    101
# Canada                    69
# Brazil                    52
# United Kingdom            46
# Germany                   44
# Israel                    36
# Australia                 28
# Singapore                 21
# Indonesia                 16
# Sweden                    15
# China                     10
# United Arab Emirates       6
# Hong Kong                  5
# Estonia                    4
# Nigeria                    4
# Kenya                      4
# Denmark                    4
# Netherlands                4
# Pakistan                   3
# Norway                     3
# Malaysia                   3
# Seychelles                 3
# Vietnam                    3
# Colombia                   3
# Luxembourg                 2
# Romania                    2
# Ireland                    2
# Austria                    2
# ...

# %%
print(f'Total number of industries affected by layoffs: {len(layoffs.industry.unique())}')
print()
print('Number per industry:')
layoffs.industry.value_counts()
# Out:
# Total number of industries affected by layoffs: 28
#
# Number per industry:
# Finance           195
# Retail            135
# Healthcare        111
# Transportation    102
# Marketing         101
# Food               97
# Real Estate        92
# Consumer           78
# Education          68
# Media              68
# Travel             61
# Other              60
# Data               56
# Crypto             50
# Security           44
# HR                 44
# Logistics          34
# Infrastructure     33
# Recruiting         27
# Support            25
# Sales              22
# Fitness            22
# Product            22
# Construction       13
# Energy             10
# Legal               7
# Aerospace           6
# Name: industry, dtype: int64

# %%
layoffs.date.unique()
# Out:
# array(['2022-11-16', '2022-11-15', '2022-11-14', '2022-11-11',
#        '2022-11-10', '2022-11-09', '2022-11-08', '2022-11-07',
#        '2022-11-06', '2022-11-04', '2022-11-03', '2022-11-02',
#        '2022-11-01', '2022-10-31', '2022-10-28', '2022-10-27',
#        '2022-10-26', '2022-10-25', '2022-10-24', '2022-10-23',
#        '2022-10-21', '2022-10-20', '2022-10-19', '2022-10-18',
#        '2022-10-17', '2022-10-16', '2022-10-14', '2022-10-13',
#        '2022-10-12', '2022-10-11', '2022-10-10', '2022-10-07',
#        '2022-10-06', '2022-10-05', '2022-10-04', '2022-10-03',
#        '2022-10-02', '2022-09-30', '2022-09-29', '2022-09-28',
#        '2022-09-27', '2022-09-24', '2022-09-23', '2022-09-22',
#        '2022-09-21', '2022-09-20', '2022-09-19', '2022-09-18',
#        '2022-09-16', '2022-09-15', '2022-09-14', '2022-09-13',
#        '2022-09-12', '2022-09-09', '2022-09-08', '2022-09-07',
#        '2022-09-06', '2022-09-02', '2022-09-01', '2022-08-31',
# ...

# %%
len(layoffs.date.unique())

layoffs['date'] = pd.to_datetime(layoffs['date'])

print(f'Earliest date in the dataset {layoffs.date.min()}')
print(f'Latest date in the dataset {layoffs.date.max()}')
# Out:
# Earliest date in the dataset 2020-03-11 00:00:00
# Latest date in the dataset 2022-11-16 00:00:00

# %%
import datetime as dt

layoffs['year'] = layoffs.date.dt.year
layoffs['month'] = layoffs.date.dt.month
layoffs['day'] = layoffs.date.dt.day

layoffs
# Out:
#             company        location        industry  total_laid_off  \
# 0            Amazon         Seattle          Retail         10000.0
# 1             Asana     SF Bay Area           Other           180.0
# 2          Protocol     SF Bay Area           Media            60.0
# 3     Nirvana Money           Miami         Finance             NaN
# 4             Sema4        Stamford      Healthcare           500.0
# ...             ...             ...             ...             ...
# 1581        Service     Los Angeles          Travel             NaN
# 1582   HopSkipDrive     Los Angeles  Transportation             8.0
# 1583    Panda Squad     SF Bay Area        Consumer             6.0
# 1584  Tamara Mellon     Los Angeles          Retail            20.0
# 1585       EasyPost  Salt Lake City       Logistics            75.0
#
#       percentage_laid_off       date     stage        country  funds_raised  \
# ...

# %%
print(f'Total number of employees laid off are {layoffs.total_laid_off.sum()}')
# Out:
# Total number of employees laid off are 227658.0

# %%
twenty_20 = layoffs.loc[layoffs['year'] == 2020]
twenty_21 = layoffs.loc[layoffs['year'] == 2021]
twenty_22 = layoffs.loc[layoffs['year'] == 2022]

print(f'Total number of layoffs in 2020: {twenty_20.total_laid_off.sum()}')
print()
print(f'Total number of layoffs in 2021: {twenty_21.total_laid_off.sum()}')
print()
print(f'Total number of layoffs in 2022: {twenty_22.total_laid_off.sum()}')
# Out:
# Total number of layoffs in 2020: 80968.0
#
# Total number of layoffs in 2021: 15023.0
#
# Total number of layoffs in 2022: 131667.0

# %%
# layoffs.loc[layoffs['country'] == 'South Africa', ['total_laid_off']].sum()

# layoffs.query("country == South Africa")['total_laid_off'].sum()
layoffs.groupby('country')['total_laid_off'].sum()
# df.query("a == 1")['b'].sum()
# Out:
# country
# Argentina                  130.0
# Australia                  995.0
# Austria                    470.0
# Bahrain                      0.0
# Belgium                      0.0
# Brazil                    7225.0
# Bulgaria                   120.0
# Canada                    4989.0
# Chile                       30.0
# China                     4430.0
# Colombia                    30.0
# Czech Republic               0.0
# Denmark                    240.0
# Egypt                        0.0
# Estonia                    267.0
# Finland                    250.0
# France                       0.0
# Germany                   3538.0
# Greece                       0.0
# Hong Kong                  730.0
# Hungary                      0.0
# India                    29231.0
# Indonesia                 2230.0
# Ireland                     21.0
# Israel                    2108.0
# Kenya                      138.0
# Lithuania                   60.0
# Luxembourg                   0.0
# ...

# %%
# for x in layoffs['country'].unique():
#     y = layoffs.loc[layoffs['country'] == x, ['total_laid_off']].sum()

#     print({x:y})
    
#     countries = pd.DataFrame(columns={'country':x,'total_laid_off':y})

# %%
layoffs.groupby('industry')['total_laid_off'].sum()
# Out:
# industry
# Aerospace           661.0
# Construction       3820.0
# Consumer          28149.0
# Crypto             6561.0
# Data               2342.0
# Education         10135.0
# Energy              802.0
# Finance           19289.0
# Fitness            8238.0
# Food              21885.0
# HR                 1342.0
# Healthcare        10736.0
# Infrastructure     1258.0
# Legal               470.0
# Logistics          2731.0
# Marketing          5594.0
# Media              2542.0
# Other              5187.0
# Product             660.0
# Real Estate       15488.0
# Recruiting         2575.0
# Retail            26907.0
# Sales              3744.0
# Security           3483.0
# Support            1440.0
# Transportation    26475.0
# Travel            14876.0
# Name: total_laid_off, dtype: float64

# %%
# for x in layoffs['industry'].unique():
#     y = layoffs.loc[layoffs['industry'] == x, ['total_laid_off']].sum()

#     print({x:y})

# %%
layoffs['percentage_laid_off'].min()
# Out:
# 0.0

# %%
print('Percentage of country workforce that got trenched:')

layoffs.groupby('country')['percentage_laid_off'].mean()
# Out:
# Percentage of country workforce that got trenched:
# country
# Argentina               0.250000
# Australia               0.373500
# Austria                 0.270000
# Bahrain                      NaN
# Belgium                      NaN
# Brazil                  0.208750
# Bulgaria                0.100000
# Canada                  0.229615
# Chile                        NaN
# China                   0.196667
# Colombia                0.030000
# Czech Republic               NaN
# Denmark                 0.675000
# Egypt                        NaN
# Estonia                 0.180000
# Finland                 0.170000
# France                       NaN
# Germany                 0.294483
# Greece                       NaN
# Hong Kong               0.132500
# Hungary                 0.140000
# India                   0.336610
# Indonesia               0.464000
# Ireland                      NaN
# Israel                  0.240357
# Kenya                   0.347500
# ...

# %%
print('Average percentage workforce that got trenched:')

layoffs.groupby('industry')['percentage_laid_off'].mean()
# Out:
# Average percentage workforce that got trenched:
# industry
# Aerospace         0.565000
# Construction      0.273000
# Consumer          0.283542
# Crypto            0.258372
# Data              0.225937
# Education         0.381463
# Energy            0.190000
# Finance           0.247883
# Fitness           0.348824
# Food              0.386091
# HR                0.273462
# Healthcare        0.280658
# Infrastructure    0.329500
# Legal             0.346000
# Logistics         0.199615
# Marketing         0.212466
# Media             0.275610
# Other             0.248571
# Product           0.278333
# Real Estate       0.319552
# Recruiting        0.319500
# Retail            0.308333
# Sales             0.106542
# Security          0.196000
# Support           0.275000
# Transportation    0.224914
# Travel            0.367750
# Name: percentage_laid_off, dtype: float64

# %%
print('Average of workforce trenched per stage:')

layoffs.groupby('stage')['percentage_laid_off'].mean()
# Out:
# Average of workforce trenched per stage:
# stage
# Acquired          0.349357
# IPO               0.151609
# Private Equity    0.198333
# Seed              0.692683
# Series A          0.383855
# Series B          0.344118
# Series C          0.237587
# Series D          0.188425
# Series E          0.192881
# Series F          0.159524
# Series G          0.184000
# Series H          0.115455
# Series I          0.085000
# Series J          0.240000
# Unknown           0.321726
# Name: percentage_laid_off, dtype: float64

# %%
print('How much each country in the dataset is worth:')

layoffs.groupby('country')['funds_raised'].sum()
# Out:
# How much each country in the dataset is worth:
# country
# Argentina                   11.0000
# Australia                 1585.0000
# Austria                   1232.0000
# Bahrain                    202.0000
# Belgium                    596.0000
# Brazil                   12705.7000
# Bulgaria                     0.0000
# Canada                    8125.3000
# Chile                      204.0000
# China                    44708.0000
# Colombia                   584.0000
# Czech Republic              41.0000
# Denmark                    216.0000
# Egypt                       33.0000
# Estonia                    269.0000
# Finland                    169.0000
# France                     100.0000
# Germany                  31169.9800
# Greece                       6.0000
# Hong Kong                 1324.0000
# Hungary                     83.0000
# India                   112716.6000
# Indonesia                 7931.0000
# Ireland                    681.0000
# ...

# %%
print('How much each industry is worth:')

layoffs.groupby('industry')['funds_raised'].sum()
# Out:
# How much each industry is worth:
# industry
# Aerospace           3477.0000
# Construction        5394.0000
# Consumer          101784.3000
# Crypto             10977.0000
# Data               14253.6000
# Education          15515.8000
# Energy              3974.0000
# Finance            79319.7800
# Fitness            10218.6000
# Food               67831.9755
# HR                  3876.7000
# Healthcare         30912.0000
# Infrastructure      5844.0000
# Legal               1015.0000
# Logistics           7950.0000
# Marketing          13139.7000
# Media             499087.8000
# Other              19541.0000
# Product             3323.2000
# Real Estate        93930.5000
# Recruiting          1944.0000
# Retail             43518.1000
# Sales               3354.4000
# Security           12469.0000
# Support             3294.6000
# Transportation    251357.7400
# Travel             24571.5000
# Name: funds_raised, dtype: float64

# %%
country_comp = layoffs.groupby('country')['funds_raised', 'total_laid_off'].sum()
country_comp
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3552\1321684694.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   country_comp = layoffs.groupby('country')['funds_raised', 'total_laid_off'].sum()
#                       funds_raised  total_laid_off
# country
# Argentina                  11.0000           130.0
# Australia                1585.0000           995.0
# Austria                  1232.0000           470.0
# Bahrain                   202.0000             0.0
# Belgium                   596.0000             0.0
# Brazil                  12705.7000          7225.0
# Bulgaria                    0.0000           120.0
# Canada                   8125.3000          4989.0
# Chile                     204.0000            30.0
# China                   44708.0000          4430.0
# Colombia                  584.0000            30.0
# Czech Republic             41.0000             0.0
# ...

# %%
industry_comp = layoffs.groupby('industry')['funds_raised', 'total_laid_off'].sum()
industry_comp
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3552\2666813799.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   industry_comp = layoffs.groupby('industry')['funds_raised', 'total_laid_off'].sum()
#                 funds_raised  total_laid_off
# industry
# Aerospace          3477.0000           661.0
# Construction       5394.0000          3820.0
# Consumer         101784.3000         28149.0
# Crypto            10977.0000          6561.0
# Data              14253.6000          2342.0
# Education         15515.8000         10135.0
# Energy             3974.0000           802.0
# Finance           79319.7800         19289.0
# Fitness           10218.6000          8238.0
# Food              67831.9755         21885.0
# HR                 3876.7000          1342.0
# Healthcare        30912.0000         10736.0
# Infrastructure     5844.0000          1258.0
# Legal              1015.0000           470.0
# ...

# %%
industry_comp = layoffs.groupby('industry')['funds_raised', 'total_laid_off'].sum()
industry_comp

plt.figure()
plt.scatter(industry_comp['total_laid_off'],industry_comp['funds_raised'])
plt.xlabel('Laid Off Employees')
plt.ylabel('Funds Raised')
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3552\4290979295.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   industry_comp = layoffs.groupby('industry')['funds_raised', 'total_laid_off'].sum()

# %%
country_comp = layoffs.groupby('country')['funds_raised', 'total_laid_off'].sum()
country_comp

plt.figure()
plt.scatter(country_comp['total_laid_off'],country_comp['funds_raised'])
plt.xlabel('Laid Off Employees')
plt.ylabel('Funds Raised')
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3552\555398158.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   country_comp = layoffs.groupby('country')['funds_raised', 'total_laid_off'].sum()

# %%
location_comp = layoffs.groupby(['location', 'country'])['funds_raised', 'total_laid_off'].sum()


with pd.option_context("display.max_rows", None):
    display(location_comp)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3552\1344002626.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   location_comp = layoffs.groupby(['location', 'country'])['funds_raised', 'total_laid_off'].sum()
#                                        funds_raised  total_laid_off
# location         country
# Ahmedabad        India                     200.0000           500.0
# Amsterdam        Netherlands             27500.0000          4990.0
# Ann Arbor        United States              59.0000            40.0
# Athens           Greece                      6.0000             0.0
# Atlanta          United States            2538.0000          1461.0
# Auckland         New Zealand               159.0000            45.0
# Austin           United States           23437.3000          1842.0
# Baltimore        United States             205.0000            20.0
# ...

# %%
plt.figure()
plt.scatter(location_comp['total_laid_off'],location_comp['funds_raised'])
plt.xlabel('Laid Off Employees')
plt.ylabel('Funds Raised')
plt.show()

# %%
stage_comp = layoffs.groupby('stage')['funds_raised','total_laid_off'].sum()
stage_comp

# plt.figure()
# plt.scatter(country_comp['total_laid_off'],country_comp['funds_raised'])
# plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3552\2074866960.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   stage_comp = layoffs.groupby('stage')['funds_raised','total_laid_off'].sum()
#                 funds_raised  total_laid_off
# stage
# Acquired          18208.4000         18199.0
# IPO              845638.9000         85748.0
# Private Equity    22770.5400          5596.0
# Seed                235.6755          1452.0
# Series A           4547.4000          4541.0
# Series B          21337.5800         12161.0
# Series C          43111.8000         15454.0
# Series D          54800.6000         14905.0
# Series E          43847.0000         13477.0
# Series F          34961.8000          7655.0
# Series G          13291.0000          3406.0
# Series H          89154.0000          6369.0
# Series I          15178.0000          2645.0
# Series J          15628.0000          3120.0
# ...

# %%
plt.figure()
plt.scatter(stage_comp['total_laid_off'],stage_comp['funds_raised'])
plt.xlabel('Laid Off Employees')
plt.ylabel('Funds Raised')
plt.show()
